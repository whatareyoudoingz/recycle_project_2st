# %%
# 코랩과 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# GPU 정보 확인
# !nvidia-smi
# Out:
# Wed Jan 17 19:53:28 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0 Off |                  Off |
# |  0%   37C    P8    26W / 450W |     71MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd /content/drive/MyDrive/cpr_segmentation/datasets
# Out:
# /content/drive/MyDrive/cpr_segmentation/datasets

# %%
# 임포트 라이브러리
import os
# !pip install ultralytics==8.0.28 # YOLOv8 설치
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# 현재 작업 디렉토리 출력
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/cpr_segmentation/datasets

# %%
model = YOLO(model='yolov8x-seg.pt')

model.train(data='/project/datacamp/team9/t9user2/cpr_segmentation/datasets/data.yaml', epochs=50)
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24209MiB)
# ...

# %%
# visualization
Image(filename=f'/content/drive/MyDrive/cpr_segmentation/datasets/runs/segment/train7/val_batch0_labels.jpg', width=600)

# %%
# visualization
Image(filename=f'/content/drive/MyDrive/cpr_segmentation/datasets/runs/segment/train7/BoxP_curve.png', width=600)
# Out:
# /project/datacamp/team9/t9user2/cpr_segmentation

# %%
# visualization
Image(filename=f'/content/drive/MyDrive/cpr_segmentation/datasets/runs/segment/train7/MaskP_curve.png', width=600)
# Out:
# /project/datacamp/team9/t9user2/cpr_segmentation
